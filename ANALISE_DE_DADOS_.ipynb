# %% [markdown]
# <a href="https://colab.research.google.com/github/tiagomelo33/deeplearningandmachine/blob/main/ANALISE_DE_DADOS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %% [markdown]
# # Nova seção

# %% [markdown]
# # Nova seção

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f20d83ca-0724-4484-bef4-d23ef577cf6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f20d83ca-0724-4484-bef4-d23ef577cf6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris.csv

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['iris.csv']))
print(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
planta = pd.read_csv('iris.csv')
planta.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
planta.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
planta.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
planta.shape
# Out:
# (150, 5)

# %%
planta.columns = ['sepala_comprimento','sepala_largura','petala_comprimento','petala_largura','especie']

# %%
planta.head()
# Out:
#    sepala_comprimento  sepala_largura  petala_comprimento  petala_largura  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
# 2                 4.7             3.2                 1.3             0.2
# 3                 4.6             3.1                 1.5             0.2
# 4                 5.0             3.6                 1.4             0.2
#
#   especie
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa

# %%
planta[planta['sepala_comprimento'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [sepala_comprimento, sepala_largura, petala_comprimento, petala_largura, especie]
# Index: []

# %%
planta['especie'].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: especie, dtype: int64

# %%
planta['especie'].value_counts().head(10).plot(kind='bar',figsize=(11,5),grid = False, rot=0, color ='blue')
plt.title('Conjunto de dados de Flor Iris')
plt.xlabel('Classificação')
plt.ylabel('Quantidade')
plt.show()
